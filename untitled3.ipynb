# %% [markdown]
# <a href="https://colab.research.google.com/github/sumitghanwat0309-wq/Student-Marks-Analysis/blob/main/untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/boston.csv")
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9

# %%
df['AGE'] = df['AGE'].fillna(df['AGE'].mean(),inplace=True)
df
# Out:
# /tmp/ipykernel_735/228938982.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['AGE'] = df['AGE'].fillna(df['AGE'].mean(),inplace=True)
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  None  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  None  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  None  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  None  6.0622    3  222.0
# ...

# %%
df.shape
# Out:
# (506, 14)

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      0 non-null      object
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(2), object(1)
# memory usage: 55.5+ KB

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               DIS         RAD         TAX     PTRATIO           B       LSTAT  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.795043    9.549407  408.237154   18.455534  356.674032   12.653063
# ...

# %%
df.sort_values(by="AGE")
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  None  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  None  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  None  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  None  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  None  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  None  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  None  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  None  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  None  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  None  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# AGE        506
# CRIM         0
# INDUS        0
# CHAS         0
# NOX          0
# ZN           0
# RM           0
# DIS          0
# RAD          0
# TAX          0
# PTRATIO      0
# B            0
# LSTAT        0
# MEDV         0
# dtype: int64

# %%
df.groupby('LSTAT')['MEDV'].mean()
# Out:
# LSTAT
# 1.73     50.0
# 1.92     50.0
# 1.98     34.9
# 2.47     41.7
# 2.87     36.4
#          ...
# 34.37    17.9
# 34.41    14.4
# 34.77    13.8
# 36.98     7.0
# 37.97    13.8
# Name: MEDV, Length: 455, dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  None  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  None  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  None  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  None  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  None  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  None  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  None  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  None  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  None  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  None  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
df.drop(columns=['NOX'],inplace=True)
df
# Out:
#         CRIM    ZN  INDUS  CHAS     RM   AGE     DIS  RAD    TAX  PTRATIO  \
# 0    0.00632  18.0   2.31     0  6.575  None  4.0900    1  296.0     15.3
# 1    0.02731   0.0   7.07     0  6.421  None  4.9671    2  242.0     17.8
# 2    0.02729   0.0   7.07     0  7.185  None  4.9671    2  242.0     17.8
# 3    0.03237   0.0   2.18     0  6.998  None  6.0622    3  222.0     18.7
# 4    0.06905   0.0   2.18     0  7.147  None  6.0622    3  222.0     18.7
# ..       ...   ...    ...   ...    ...   ...     ...  ...    ...      ...
# 501  0.06263   0.0  11.93     0  6.593  None  2.4786    1  273.0     21.0
# 502  0.04527   0.0  11.93     0  6.120  None  2.2875    1  273.0     21.0
# 503  0.06076   0.0  11.93     0  6.976  None  2.1675    1  273.0     21.0
# 504  0.10959   0.0  11.93     0  6.794  None  2.3889    1  273.0     21.0
# 505  0.04741   0.0  11.93     0  6.030  None  2.5050    1  273.0     21.0
#
#           B  LSTAT  MEDV
# 0    396.90   4.98  24.0
# 1    396.90   9.14  21.6
# ...

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(numeric_only=True),cbar=False)
plt.show()

# %%
sns.histplot(df['MEDV'],kde = True)
plt.title("House Price Distribution")
plt.show()

# %%
corr = df.corr()

plt.figure(figsize=(10.6, 6))
sns.heatmap(corr, annot= True, cmap="coolwarm")
plt.show()

# %%
corr['MEDV'].sort_values(ascending=False)
# Out:
# MEDV       1.000000
# RM         0.695360
# ZN         0.360445
# B          0.333461
# DIS        0.249929
# CHAS       0.175260
# RAD       -0.381626
# CRIM      -0.388305
# TAX       -0.468536
# INDUS     -0.483725
# PTRATIO   -0.507787
# LSTAT     -0.737663
# AGE             NaN
# Name: MEDV, dtype: float64

# %%
sns.scatterplot(x ="LSTAT" , y = "MEDV", data=df)
plt.show()

# %%
sns.scatterplot(x= "RM",y = "MEDV",data = df)
plt.show()

# %%
sns.scatterplot(x= "ZN",y = "MEDV",data = df)
plt.show()

# %%
sns.boxplot(df['MEDV'])
plt.show()

# %%
df.mean()
# Out:
# CRIM         3.613524
# ZN          11.363636
# INDUS       11.136779
# CHAS          0.06917
# RM           6.284634
# AGE               NaN
# DIS          3.795043
# RAD          9.549407
# TAX        408.237154
# PTRATIO     18.455534
# B          356.674032
# LSTAT       12.653063
# MEDV        22.532806
# dtype: object

# %%
sns.barplot(x="RAD" , y = "MEDV", data = df)
plt.show()

# %%
df.isnull().sum()
# Out:
# CRIM         0
# ZN           0
# INDUS        0
# CHAS         0
# RM           0
# AGE        506
# DIS          0
# RAD          0
# TAX          0
# PTRATIO      0
# B            0
# LSTAT        0
# MEDV         0
# dtype: int64

# %%
df['Price_Category']= pd.cut(df['MEDV'],bins=[0,20,35,50],labels=['Low','Medium','High'])
df

counts = df['Price_Category'].value_counts()
print(counts)

counts.plot.pie(autopct ='%1.1f%%')
plt.title("House Price Distribution (MEDV)")
plt.ylabel("")
plt.show()
# Out:
# Price_Category
# Medium    243
# Low       215
# High       48
# Name: count, dtype: int64

# %%
sns.pairplot(df[['MEDV','RM','LSTAT','PTRATIO']])
plt.show()

# %% [markdown]
# Conclusion:-
# In this project, exploratory data analysis was performed on the house price dataset to understand the key factors affecting housing prices. Various techniques such as data cleaning, handling missing values, correlation analysis, and data visualization were used.
# It was observed that features like number of rooms (RM), income level (LSTAT), and other socio-economic factors have a significant impact on house prices. The analysis helped in identifying patterns, trends, and relationships within the data.Data is analyed using piecharts and plots
#
# Overall, this project provided a clear understanding of the dataset and prepared the data for building predictive models.”
